# %% [markdown]
# <a href="https://colab.research.google.com/github/sagihaider/IADS_SC_2021_Python/blob/main/Exercise_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Functions
# Most of the times, In a algorithm the statements keep repeating and it will be a tedious job to execute the same statements again and again and will consume a lot of memory and is not efficient. Enter Functions.

# %%
print("Hey Adam!")
print("Adam, How do you do?")
# Out:
# Hey Adam!
# Adam, How do you do?

# %%
def firstfunc():
    print("Hey Adam!")
    print("Adam, How do you do?")

# %%
firstfunc()
# Out:
# Hey Adam!
# Adam, How do you do?

# %% [markdown]
# **firstfunc()** every time just prints the message to a single person. We can make our function **firstfunc()** to accept arguements which will store the name and then prints respective to that accepted name. To do so, add a argument within the function as shown.

# %%
def firstfunc1(username):
    print("Hey", username + '!')
    print(username + ',' ,"How do you do?")

# %%
name1 = firstfunc1('Haider : ')
# Out:
# Hey Haider : !
# Haider : , How do you do?

# %% [markdown]
# ## Return Statement
#
# When the function results in some value and that value has to be stored in a variable or needs to be sent back or returned for further operation to the main algorithm, return statement is used.

# %%
def times(x,y):
    z = x*y
    return(z)

# %%
times(5,6)
# Out:
# 30

# %%
c = times(4,5)
print(c)
# Out:
# 20

# %%
eglist = [10,50,30,12,6,8,100]

# %%
def egfunc(eglist):
    highest = max(eglist)
    lowest = min(eglist)
    first = eglist[0]
    last = eglist[-1]
    return highest,lowest,first,last

# %%
egfunc(eglist)
# Out:
# (100, 6, 10, 100)

# %% [markdown]
# ## Implicit arguments
#
# When an argument of a function is common in majority of the cases or it is "implicit" this concept is used.

# %%
def implicitadd(x,y=3):
    return x+y

# %%
implicitadd(4)
# Out:
# 7

# %%
implicitadd(4,6)
# Out:
# 10

# %% [markdown]
# pass in python means do nothing.
